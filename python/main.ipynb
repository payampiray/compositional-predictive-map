# %% [markdown]
# # compositional-predictive-map
#
# The code for generating Figures 1-5 of the paper.
#
# Piray and Daw, 2025, Nature Communications
# Reconciling Flexibility and Efficiency: Medial Entorhinal Cortex Represents a Compositional Cognitive Map

# %%
import sim_model
import sim_detour

sim_model.main()
sim_detour.main()
# Out:
# ([<Figure size 400x400 with 1 Axes>,
#   <Figure size 400x400 with 1 Axes>,
#   <Figure size 400x400 with 1 Axes>,
#   <Figure size 400x400 with 1 Axes>],
#  'detour')

# %%
import sim_learn
import sim_plan

sim_learn.main()
sim_plan.main()
# Out:
# ([<Figure size 400x400 with 1 Axes>,
#   <Figure size 1100x700 with 1 Axes>,
#   <Figure size 400x400 with 1 Axes>,
#   <Figure size 1100x700 with 1 Axes>],
#  'plan')

# %%
import sim_hoydal_translate
import sim_hoydal_rotate

sim_hoydal_translate.main()
sim_hoydal_rotate.main()
# Out:
# ([<Figure size 700x180 with 3 Axes>], 'hoydal_rotate')

# %%
import sim_hoydal_multi
import sim_hoydal_generalize

sim_hoydal_multi.main()
sim_hoydal_generalize.main()
# Out:
# ([<Figure size 450x180 with 2 Axes>], 'hoydal_generalize')

# %%
import sim_hoydal_length
sim_hoydal_length.main()
# Out:
# ([<Figure size 850x180 with 4 Axes>, <Figure size 275x225 with 1 Axes>],
#  'hoydal_length')
