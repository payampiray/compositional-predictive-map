# %% [markdown]
# # compositional-predictive-map
#
# The code for generating Figures 1-4 of the paper.
#
# Reference:\
# https://www.biorxiv.org/content/10.1101/2024.05.16.594459

# %%
import sim_model as sim
sim.main()
import sim_plan as sim
sim.main()
# Out:
# ([<Figure size 400x400 with 1 Axes>,
#   <Figure size 700x400 with 1 Axes>,
#   <Figure size 400x400 with 1 Axes>,
#   <Figure size 700x400 with 1 Axes>],
#  'plan')

# %%
import sim_hoydal_translate as sim
sim.main()
import sim_hoydal_rotate as sim
sim.main()
# Out:
# ([<Figure size 700x180 with 3 Axes>], 'hoydal_rotate')

# %%
import sim_hoydal_multi as sim
sim.main()
import sim_hoydal_generalize as sim
sim.main()
# Out:
# ([<Figure size 450x180 with 2 Axes>], 'hoydal_generalize')

# %%
import sim_hoydal_length as sim
sim.main()
# Out:
# ([<Figure size 850x180 with 4 Axes>, <Figure size 275x225 with 1 Axes>],
#  'hoydal_length')
